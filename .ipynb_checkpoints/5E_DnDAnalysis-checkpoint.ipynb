# %%
#import functions
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#for in notebook graphic exploration
# %matplotlib inline

# %%
#data loading
df = pd.read_csv('1000CharSimulated.csv', index_col=0) #Setting index_col at 0 cleans up DF

# %%
df.head()
# Out:
#   RollType  strength  dexterity  constituion  intellegence  wisdom  charisma  \
# 0      3D6        12          8            7            16      17        12
# 1      3D6        11          9           17            11       4        10
# 2      3D6         6         10            8             9       8         9
# 3      3D6         8          9           14            12      16        13
# 4      3D6        11         11           11            13      11        11
#
#    str mod  dex mod  con mod  int mod  wis mod  char mod
# 0        1       -1       -2        3        3         1
# 1        0       -1        3        0       -3         0
# 2       -2        0       -1       -1       -1        -1
# 3       -1       -1        2        1        3         1
# 4        0        0        0        1        0         0

# %%
df.tail(10)
# Out:
#       RollType  strength  dexterity  constituion  intellegence  wisdom  \
# 2990  Colville        16         14           12            10      15
# 2991  Colville        18         11           10            18      10
# 2992  Colville        13         11           13             9      16
# 2993  Colville        14         16           11             9      15
# 2994  Colville        12         18           13            14      12
# 2995  Colville        13         13            9             9      15
# 2996  Colville        16          9           15            12      16
# 2997  Colville        15         14           17            15      14
# 2998  Colville        12         17            8            15      10
# 2999  Colville        11          9           16            15      14
#
#       charisma  str mod  dex mod  con mod  int mod  wis mod  char mod
# 2990        16        3        2        1        0        2         3
# 2991        14        4        0        0        4        0         2
# 2992        15        1        0        1       -1        3         2
# 2993        11        2        3        0       -1        2         0
# 2994        16        1        4        1        2        1         3
# 2995        15        1        1       -1       -1        2         2
# 2996        10        3       -1        2        1        3         0
# 2997        10        2        2        3        2        2         0
# 2998        17        1        3       -1        2        0         3
# 2999        15        0       -1        3        2        2         2

# %% [markdown]
# Bullet Points:
# -Been watching "Running the Game" and appreciating the art of creating a collective narrative
# -But also have been interested in data analysis and programming
# -To get better at both, want to combine them
#
# Created a script that generated stats three different ways
# -roll 3d6
# -roll 4d6 (dropping lowest value)
# -roll 4d6 AND two stats have to >= 15 (Matt Colville Method)
#
# Matt says he likes this method because it helps players discover their characters.  But, also having 2 stats greater than 15 ensures that they are special in some one.  That they are heros and have something that makes them unique.  So main question is, how much better are Matt's generated characters than the other methods?
#
# Other questions (I'm interested in and will help me learn data exploration)
#
# Main: How much better are Matt's characters than other characters?
#
# Other:
# -What is the correlation between stats (holding RollType constant)?  Should be zero, but want to make sure.
# -How about correlation between ability and ability modifier?
# -Who was the strongest character generated?  The weakest?
# -Could I create an if statement mapping stats to the class the character should be?

# %%
df['ability_average']=df.iloc[:,1:7].mean(axis=1)
df['mod_average']=df.iloc[:,7:12].mean(axis=1)
#pd.mean(axis = 1) if 0 avearge down rows, if 1, average across columns

# %%
df.sample(5) #sample is cool because it randomly grabs however many data points you request
# Out:
#         RollType  strength  dexterity  constituion  intellegence  wisdom  \
# 793          3D6        12          6           12            11      16
# 2004    Colville        13         12           14            16      13
# 790          3D6        14         12            8            14      14
# 87           3D6         4          8           10             7      17
# 1649  4D6DropLow         8          8            5            11      13
#
#       charisma  str mod  dex mod  con mod  int mod  wis mod  char mod  \
# 793         16        1       -2        1        0        3         3
# 2004        15        1        1        2        3        1         2
# 790         11        2        1       -1        2        2         0
# 87           5       -3       -1        0       -2        3        -3
# 1649         8       -1       -1       -3        0        1        -1
#
#       ability_average  mod_average
# 793         12.166667          0.6
# 2004        13.833333          1.6
# 790         12.166667          1.2
# 87           8.500000         -0.6
# 1649         8.833333         -0.8

# %%
df.describe()
# Out:
#           strength    dexterity  constituion  intellegence       wisdom  \
# count  3000.000000  3000.000000  3000.000000   3000.000000  3000.000000
# mean     11.940000    11.873000    11.895333     11.882333    11.947000
# std       3.107778     3.174518     3.092070      3.118824     3.109997
# min       3.000000     3.000000     3.000000      3.000000     3.000000
# 25%      10.000000    10.000000    10.000000     10.000000    10.000000
# 50%      12.000000    12.000000    12.000000     12.000000    12.000000
# 75%      14.000000    14.000000    14.000000     14.000000    14.000000
# max      18.000000    18.000000    18.000000     18.000000    18.000000
#
#        charisma      str mod      dex mod      con mod      int mod  \
# count  3000.000  3000.000000  3000.000000  3000.000000  3000.000000
# mean     11.964     0.720667     0.684667     0.694667     0.683000
# std       3.139     1.567841     1.611448     1.565542     1.578187
# min       3.000    -4.000000    -4.000000    -4.000000    -4.000000
# 25%      10.000     0.000000     0.000000     0.000000     0.000000
# 50%      12.000     1.000000     1.000000     1.000000     1.000000
# 75%      14.000     2.000000     2.000000     2.000000     2.000000
# max      18.000     4.000000     4.000000     4.000000     4.000000
#
#            wis mod     char mod  ability_average  mod_average
# count  3000.000000  3000.000000      3000.000000  3000.000000
# mean      0.715667     0.735667        11.916944     0.699733
# std       1.567899     1.582602         1.546388     0.824710
# min      -4.000000    -4.000000         6.500000    -2.200000
# 25%       0.000000     0.000000        10.833333     0.200000
# 50%       1.000000     1.000000        12.166667     0.800000
# 75%       2.000000     2.000000        13.166667     1.200000
# max       4.000000     4.000000        15.833333     2.800000

# %%
df.groupby(['RollType']).mean() #need to have groupby columns in [] otherwise throws an error
#df.groupby(['RollType']).std()
# Out:
#             strength  dexterity  constituion  intellegence  wisdom  charisma  \
# RollType
# 3D6           10.480     10.457       10.419        10.458  10.556    10.582
# 4D6DropLow    12.286     12.194       12.147        12.070  12.222    12.203
# Colville      13.054     12.968       13.120        13.119  13.063    13.107
#
#             str mod  dex mod  con mod  int mod  wis mod  char mod  \
# RollType
# 3D6          -0.010   -0.029   -0.037   -0.026    0.030     0.057
# 4D6DropLow    0.902    0.849    0.819    0.779    0.858     0.847
# Colville      1.270    1.234    1.302    1.296    1.259     1.303
#
#             ability_average  mod_average
# RollType
# 3D6               10.492000      -0.0144
# 4D6DropLow        12.187000       0.8414
# Colville          13.071833       1.2722

# %%
df[['RollType','strength','dexterity']].mean() # this works
# Out:
# strength     11.940
# dexterity    11.873
# dtype: float64

# %%
df[['RollType','strength','dexterity']].groupby('RollType').mean() # this works
# Out:
#             strength  dexterity
# RollType
# 3D6           10.480     10.457
# 4D6DropLow    12.286     12.194
# Colville      13.054     12.968

# %%
df[['RollType','strength','dexterity']].groupby('RollType').describe() # this works
# Out:
#                     dexterity     strength
# RollType
# 3D6        count  1000.000000  1000.000000
#            mean     10.457000    10.480000
#            std       3.069132     2.973624
#            min       3.000000     3.000000
#            25%       8.000000     8.000000
#            50%      10.000000    10.000000
#            75%      13.000000    13.000000
#            max      18.000000    18.000000
# 4D6DropLow count  1000.000000  1000.000000
#            mean     12.194000    12.286000
#            std       2.844372     2.855934
#            min       4.000000     4.000000
#            25%      10.000000    10.000000
#            50%      12.000000    12.000000
#            75%      14.000000    14.000000
#            max      18.000000    18.000000
# Colville   count  1000.000000  1000.000000
# 4D6DropLow count   1000.000000  1000.000000  1000.000000  1000.000000
#            mean      12.070000     0.841400     0.902000    12.286000
#            std        2.886422     0.649945     1.436126     2.855934
#            min        3.000000    -1.200000    -3.000000     4.000000
#            25%       10.000000     0.400000     0.000000    10.000000
#            50%       12.000000     0.800000     1.000000    12.000000
#            75%       14.000000     1.200000     2.000000    14.000000
#            max       18.000000     2.600000     4.000000    18.000000
# Colville   count   1000.000000  1000.000000  1000.000000  1000.000000
#            mean      13.119000     1.272200     1.270000    13.054000
#            std        3.021915     0.558228     1.476238     2.915405
#            min        3.000000    -0.800000    -4.000000     3.000000
#            25%       11.000000     1.000000     0.000000    11.000000
#            50%       14.000000     1.200000     1.000000    13.000000
#            75%       15.000000     1.600000     2.000000    15.000000
#            max       18.000000     2.800000     4.000000    18.000000
#
#                       wis mod       wisdom
# RollType
# 3D6        count  1000.000000  1000.000000
#            mean      0.030000    10.556000
#            std       1.458502     2.902290
#            min      -4.000000     3.000000
#            25%      -1.000000     8.000000
#            50%       0.000000    11.000000
#            75%       1.000000    13.000000
#            max       4.000000    18.000000
# 4D6DropLow count  1000.000000  1000.000000
#            mean      0.858000    12.222000
#            std       1.466966     2.894321
#            min      -4.000000     3.000000
#            25%       0.000000    10.000000
#            50%       1.000000    12.000000
#            75%       2.000000    14.000000
#            max       4.000000    18.000000
# Colville   count  1000.000000  1000.000000
#            mean      1.259000    13.063000
#            std       1.521260     2.995998
#            min      -3.000000     4.000000
#            25%       0.000000    11.000000
#            50%       1.000000    13.000000
#            75%       2.000000    15.000000
#            max       4.000000    18.000000

# %%
df.groupby('RollType').ability_average.hist(alpha=0.7)
# Out:
# RollType
# 3D6           Axes(0.125,0.125;0.775x0.775)
# 4D6DropLow    Axes(0.125,0.125;0.775x0.775)
# Colville      Axes(0.125,0.125;0.775x0.775)
# Name: ability_average, dtype: object

# %%
df.groupby('RollType').ability_average.plot(kind='hist',alpha=.6,legend=True,bins = 40)
# Out:
# RollType
# 3D6           Axes(0.125,0.125;0.775x0.775)
# 4D6DropLow    Axes(0.125,0.125;0.775x0.775)
# Colville      Axes(0.125,0.125;0.775x0.775)
# Name: ability_average, dtype: object

# %%
df.groupby('RollType').max()
# Out:
#             strength  dexterity  constituion  intellegence  wisdom  charisma  \
# RollType
# 3D6               18         18           18            17      18        18
# 4D6DropLow        18         18           18            18      18        18
# Colville          18         18           18            18      18        18
#
#             str mod  dex mod  con mod  int mod  wis mod  char mod  \
# RollType
# 3D6               4        4        4        3        4         4
# 4D6DropLow        4        4        4        4        4         4
# Colville          4        4        4        4        4         4
#
#             ability_average  mod_average
# RollType
# 3D6               14.500000     1.833333
# 4D6DropLow        15.333333     2.500000
# Colville          15.833333     2.833333

# %%
#Let's look at the best of the best for each d roll.  To do so, can filter for the max ability average
print(df[(df.RollType == '3D6') & (df.ability_average >= 14.5)])

print(df[(df.RollType == '4D6DropLow') & (df.ability_average >= 15.3)])

print(df[(df.RollType == 'Colville') & (df.ability_average >= 15.83)])
# Out:
#     RollType  strength  dexterity  constituion  intellegence  wisdom  \
# 577      3D6        16         13           17            15      13
#
#      charisma  str mod  dex mod  con mod  int mod  wis mod  char mod  \
# 577        13        3        1        3        2        1         1
#
#      ability_average  mod_average
# 577             14.5          2.0
#         RollType  strength  dexterity  constituion  intellegence  wisdom  \
# 1866  4D6DropLow        18         15           13            16      16
#
#       charisma  str mod  dex mod  con mod  int mod  wis mod  char mod  \
# 1866        14        4        2        1        3        3         2
#
#       ability_average  mod_average
# 1866        15.333333          2.6
#       RollType  strength  dexterity  constituion  intellegence  wisdom  \
# 2723  Colville        18         14           18            15      14
#
#       charisma  str mod  dex mod  con mod  int mod  wis mod  char mod  \
# 2723        16        4        2        4        2        2         3
#
#       ability_average  mod_average
# 2723        15.833333          2.8

# %%
#Your strongest characters
df.loc[[577,1866,2723],:]
# Out:
#         RollType  strength  dexterity  constituion  intellegence  wisdom  \
# 577          3D6        16         13           17            15      13
# 1866  4D6DropLow        18         15           13            16      16
# 2723    Colville        18         14           18            15      14
#
#       charisma  str mod  dex mod  con mod  int mod  wis mod  char mod  \
# 577         13        3        1        3        2        1         1
# 1866        14        4        2        1        3        3         2
# 2723        16        4        2        4        2        2         3
#
#       ability_average  mod_average
# 577         14.500000          2.0
# 1866        15.333333          2.6
# 2723        15.833333          2.8

# %%
df.groupby('RollType').min()
# Out:
#             strength  dexterity  constituion  intellegence  wisdom  charisma  \
# RollType
# 3D6                3          3            3             3       3         3
# 4D6DropLow         4          4            3             3       3         3
# Colville           3          4            4             3       4         4
#
#             str mod  dex mod  con mod  int mod  wis mod  char mod  \
# RollType
# 3D6              -4       -4       -4       -4       -4        -4
# 4D6DropLow       -3       -3       -4       -4       -4        -4
# Colville         -4       -3       -3       -4       -3        -3
#
#             ability_average  mod_average
# RollType
# 3D6                6.500000         -2.2
# 4D6DropLow         8.333333         -1.2
# Colville           9.833333         -0.8

# %%
#Let's look at the best of the best for each d roll.  To do so, can filter for the max ability average
print(df[(df.RollType == '3D6') & (df.ability_average <= 6.5)])

print(df[(df.RollType == '4D6DropLow') & (df.ability_average <= 8.4)])

print(df[(df.RollType == 'Colville') & (df.ability_average <= 10)])
# Out:
#     RollType  strength  dexterity  constituion  intellegence  wisdom  \
# 182      3D6        10          8            6             6       5
#
#      charisma  str mod  dex mod  con mod  int mod  wis mod  char mod  \
# 182         4        0       -1       -2       -2       -3        -3
#
#      ability_average  mod_average
# 182              6.5         -1.6
#         RollType  strength  dexterity  constituion  intellegence  wisdom  \
# 1228  4D6DropLow         6          9            6            10       9
#
#       charisma  str mod  dex mod  con mod  int mod  wis mod  char mod  \
# 1228        10       -2       -1       -2        0       -1         0
#
#       ability_average  mod_average
# 1228         8.333333         -1.2
#       RollType  strength  dexterity  constituion  intellegence  wisdom  \
# 2264  Colville        15         15            9             5       9
#
#       charisma  str mod  dex mod  con mod  int mod  wis mod  char mod  \
# 2264         6        2        2       -1       -3       -1        -2
#
#       ability_average  mod_average
# 2264         9.833333         -0.2

# %%
#Your strongest characters
df.loc[[182,1228,2264],:]
# Out:
#         RollType  strength  dexterity  constituion  intellegence  wisdom  \
# 182          3D6        10          8            6             6       5
# 1228  4D6DropLow         6          9            6            10       9
# 2264    Colville        15         15            9             5       9
#
#       charisma  str mod  dex mod  con mod  int mod  wis mod  char mod  \
# 182          4        0       -1       -2       -2       -3        -3
# 1228        10       -2       -1       -2        0       -1         0
# 2264         6        2        2       -1       -3       -1        -2
#
#       ability_average  mod_average
# 182          6.500000         -1.6
# 1228         8.333333         -1.2
# 2264         9.833333         -0.2
